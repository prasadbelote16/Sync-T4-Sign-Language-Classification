# %% [markdown]
# ### Name: Prasad Uttam Belote
#
# ### Task-4: Sign Language Classification

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense, Dropout
import warnings

sns.set()
# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read,Prepare and Split Data

# %%
df_train = pd.read_csv('/content/sign_mnist_train.csv')
df_train.head(-5)
# Out:
#        label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0          3     107     118     127     134     139     143     146     150
# 1          6     155     157     156     156     156     157     156     158
# 2          2     187     188     188     187     187     186     187     188
# 3          2     211     211     212     212     211     210     211     210
# 4         13     164     167     170     172     176     179     180     184
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27445     14     167     169     170     171     171     172     172     172
# 27446     19     133     135     138     141     143     144     144     145
# 27447     11     170     172     175     177     179     182     185     186
# 27448     12     149     151     153     157     159     161     164     165
# 27449     20     162     168     172     176     179     183     184     185
#
#        pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0         153  ...       207       207       207       207       206
# 1         158  ...        69       149       128        87        94
# 2         187  ...       202       201       200       199       198
# 3         210  ...       235       234       233       231       230
# 4         185  ...        92       105       105       108       133
# ...       ...  ...       ...       ...       ...       ...       ...
# 27445     171  ...       215       215       211       208       211
# 27446     145  ...         0         0         1         4         4
# 27447     187  ...       221       228       229       228       229
# 27448     168  ...       108       165       167       163       159
# 27449     188  ...       235       234       234       233       231
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# 0           206       206       204       203       202
# 1           163       175       103       135       149
# 2           199       198       195       194       195
# 3           226       225       222       229       163
# 4           163       157       163       164       179
# ...         ...       ...       ...       ...       ...
# 27445       201       167       119        75        48
# 27446         0         0         0         0         0
# 27447       229       227       228       227       227
# 27448       153       147       148       139       196
# 27449       229       228       228       227       226
#
# [27450 rows x 785 columns]

# %%
df_test = pd.read_csv('/sign_mnist_test.csv')
df_test.head(-5)
# Out:
#       label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0         6     149     149     150     150     150     151     151     150
# 1         5     126     128     131     132     133     134     135     135
# 2        10      85      88      92      96     105     123     135     143
# 3         0     203     205     207     206     207     209     210     209
# 4         3     188     191     193     195     199     201     202     203
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7162     10     130     131     131     134     133     135     137     136
# 7163      4     158     161     165     169     172     175     177     179
# 7164     14     141     144     146     149     153     156     158     161
# 7165      8     158     160     160     161     161     161     164     162
# 7166     12     169     173     177     181     183     186     189     191
#
#       pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0        151  ...       138       148       127        89        82        96
# 1        136  ...        47       104       194       183       186       184
# 2        147  ...        68       166       242       227       230       227
# 3        210  ...       154       248       247       248       253       236
# 4        203  ...        26        40        64        48        29        46
# ...      ...  ...       ...       ...       ...       ...       ...       ...
# 7162     136  ...       128       106       107        63        11       147
# 7163     181  ...        78       122       141       141       141       140
# 7164     161  ...       199       203       202       201       201       201
# 7165     162  ...       177       178       176       174       173       172
# 7166     194  ...        36        27        14        35        40        15
#
#       pixel781  pixel782  pixel783  pixel784
# 0          106       112       120       107
# 1          184       184       182       180
# 2          226       225       224       222
# 3          230       240       253       255
# 4           49        46        46        53
# ...        ...       ...       ...       ...
# 7162       194       182       176       124
# 7163       141       142       143       144
# 7164       200       200       201       201
# 7165       171       169       169       167
# 7166         8        27        42        41
#
# [7167 rows x 785 columns]

# %%
y_train = df_train['label']
df_train.drop(['label'], axis=1, inplace=True)
df_train.head(-5)
# Out:
#        pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0         107     118     127     134     139     143     146     150     153
# 1         155     157     156     156     156     157     156     158     158
# 2         187     188     188     187     187     186     187     188     187
# 3         211     211     212     212     211     210     211     210     210
# 4         164     167     170     172     176     179     180     184     185
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27445     167     169     170     171     171     172     172     172     171
# 27446     133     135     138     141     143     144     144     145     145
# 27447     170     172     175     177     179     182     185     186     187
# 27448     149     151     153     157     159     161     164     165     168
# 27449     162     168     172     176     179     183     184     185     188
#
#        pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0          156  ...       207       207       207       207       206
# 1          157  ...        69       149       128        87        94
# 2          186  ...       202       201       200       199       198
# 3          211  ...       235       234       233       231       230
# 4          186  ...        92       105       105       108       133
# ...        ...  ...       ...       ...       ...       ...       ...
# 27445      172  ...       215       215       211       208       211
# 27446      145  ...         0         0         1         4         4
# 27447      188  ...       221       228       229       228       229
# 27448      171  ...       108       165       167       163       159
# 27449      190  ...       235       234       234       233       231
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# 0           206       206       204       203       202
# 1           163       175       103       135       149
# 2           199       198       195       194       195
# 3           226       225       222       229       163
# 4           163       157       163       164       179
# ...         ...       ...       ...       ...       ...
# 27445       201       167       119        75        48
# 27446         0         0         0         0         0
# 27447       229       227       228       227       227
# 27448       153       147       148       139       196
# 27449       229       228       228       227       226
#
# [27450 rows x 784 columns]

# %%
y_test = df_test['label']
df_test.drop(['label'], axis=1, inplace=True)
df_test.head(-5)
# Out:
#       pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0        149     149     150     150     150     151     151     150     151
# 1        126     128     131     132     133     134     135     135     136
# 2         85      88      92      96     105     123     135     143     147
# 3        203     205     207     206     207     209     210     209     210
# 4        188     191     193     195     199     201     202     203     203
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7162     130     131     131     134     133     135     137     136     136
# 7163     158     161     165     169     172     175     177     179     181
# 7164     141     144     146     149     153     156     158     161     161
# 7165     158     160     160     161     161     161     164     162     162
# 7166     169     173     177     181     183     186     189     191     194
#
#       pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0         152  ...       138       148       127        89        82
# 1         138  ...        47       104       194       183       186
# 2         152  ...        68       166       242       227       230
# 3         209  ...       154       248       247       248       253
# 4         203  ...        26        40        64        48        29
# ...       ...  ...       ...       ...       ...       ...       ...
# 7162      137  ...       128       106       107        63        11
# 7163      184  ...        78       122       141       141       141
# 7164      161  ...       199       203       202       201       201
# 7165      161  ...       177       178       176       174       173
# 7166      195  ...        36        27        14        35        40
#
#       pixel780  pixel781  pixel782  pixel783  pixel784
# 0           96       106       112       120       107
# 1          184       184       184       182       180
# 2          227       226       225       224       222
# 3          236       230       240       253       255
# 4           46        49        46        46        53
# ...        ...       ...       ...       ...       ...
# 7162       147       194       182       176       124
# 7163       140       141       142       143       144
# 7164       201       200       200       201       201
# 7165       172       171       169       169       167
# 7166        15         8        27        42        41
#
# [7167 rows x 784 columns]

# %%
size  = 28
channels = 1
batch = 128
epochs = 100

# %%
X_train = df_train.values.reshape(df_train.shape[0], size, size, channels)
X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (27455, 28, 28, 1)
# X_test shape: (7172, 28, 28, 1)

# %% [markdown]
# ## Data Augmentation

# %%
datagen = ImageDataGenerator(rescale=1./255,
                             zoom_range=0.2,
                             width_shift_range=.2, height_shift_range=.2,
                             rotation_range=30,
                             brightness_range=[0.8, 1.2],
                             horizontal_flip=True)

datagenRescale = ImageDataGenerator(rescale=1./255)

X_train = datagen.flow(X_train, y_train, batch_size=batch)

X_test = datagenRescale.flow(X_test, y_test)

# %%
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i+1)
    for X_batch, Y_batch in X_train:
        image = X_batch[i]
        plt.imshow(image, cmap='gray')
        plt.xlabel(alphabet[Y_batch[i]])
        break
plt.show()

# %%
checkpoint_filepath = 'best_model.hdf5'

callback_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=False, monitor='val_accuracy', mode='max', save_best_only=True)
callback_learningrate = ReduceLROnPlateau(monitor='loss', mode='min', min_delta=0.01, patience=3, factor=.75, min_lr=0.00001, verbose=1)

callbacks = [callback_checkpoint, callback_learningrate]

# %% [markdown]
# ## Design The Neural Network

# %%
Model = Sequential([Conv2D(filters=32,  kernel_size=(3,3), activation="relu", input_shape=(size,size,channels)),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                 
                    Conv2D(filters=128,  kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                
                    Conv2D(filters=512, kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                    
                    
                    Flatten(),
                    
                    Dense(units=4096, activation="relu"),                 
                    Dropout(0.2),
                    
                    Dense(units=1024, activation="relu"),
                    Dropout(0.2),
                                  
                    Dense(units=256, activation="relu"),
                    Dropout(0.2),
                    
                    Dense(units=25, activation="softmax"),
])


Model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=["accuracy"])


Model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 13, 13, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 128)       36992
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 512)         590336
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  dropout_8 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 4096)              8392704
#
#  dropout_9 (Dropout)         (None, 4096)              0
#
#  dense_5 (Dense)             (None, 1024)              4195328
#
#  dropout_10 (Dropout)        (None, 1024)              0
#
#  dense_6 (Dense)             (None, 256)               262400
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_7 (Dense)             (None, 25)                6425
#
# =================================================================
# Total params: 13,484,505
# Trainable params: 13,484,505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training...

# %%
history = Model.fit(X_train, validation_data=X_test, epochs=100, callbacks=callbacks)
# Out:
# Epoch 1/100
# 215/215 [==============================] - 21s 88ms/step - loss: 3.1046 - accuracy: 0.0632 - val_loss: 2.9200 - val_accuracy: 0.0810 - lr: 0.0010
# Epoch 2/100
# 215/215 [==============================] - 18s 85ms/step - loss: 2.4115 - accuracy: 0.2187 - val_loss: 1.5384 - val_accuracy: 0.4424 - lr: 0.0010
# Epoch 3/100
# 215/215 [==============================] - 17s 81ms/step - loss: 1.6587 - accuracy: 0.4270 - val_loss: 1.0523 - val_accuracy: 0.6189 - lr: 0.0010
# Epoch 4/100
# 215/215 [==============================] - 18s 84ms/step - loss: 1.2423 - accuracy: 0.5626 - val_loss: 0.6816 - val_accuracy: 0.7352 - lr: 0.0010
# Epoch 5/100
# 215/215 [==============================] - 17s 81ms/step - loss: 1.0017 - accuracy: 0.6459 - val_loss: 0.4782 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 6/100
# 215/215 [==============================] - 18s 82ms/step - loss: 0.8361 - accuracy: 0.7041 - val_loss: 0.3945 - val_accuracy: 0.8441 - lr: 0.0010
# Epoch 7/100
# 215/215 [==============================] - 18s 82ms/step - loss: 0.7206 - accuracy: 0.7462 - val_loss: 0.2924 - val_accuracy: 0.8889 - lr: 0.0010
# Epoch 8/100
# 215/215 [==============================] - 18s 85ms/step - loss: 0.6351 - accuracy: 0.7768 - val_loss: 0.1536 - val_accuracy: 0.9474 - lr: 0.0010
# Epoch 9/100
# 215/215 [==============================] - 18s 82ms/step - loss: 0.5591 - accuracy: 0.8062 - val_loss: 0.1189 - val_accuracy: 0.9682 - lr: 0.0010
# Epoch 10/100
# 215/215 [==============================] - 19s 88ms/step - loss: 0.5093 - accuracy: 0.8266 - val_loss: 0.0828 - val_accuracy: 0.9799 - lr: 0.0010
# Epoch 11/100
# 215/215 [==============================] - 18s 84ms/step - loss: 0
ReduceLROnPlateau reducing learning rate to 4.223513315082528e-05.
# 215/215 [==============================] - 17s 80ms/step - loss: 0.0699 - accuracy: 0.9774 - val_loss: 6.4561e-04 - val_accuracy: 1.0000 - lr: 5.6314e-05
# Epoch 72/100
# 215/215 [==============================] - 18s 83ms/step - loss: 0.0699 - accuracy: 0.9783 - val_loss: 3.6620e-04 - val_accuracy: 1.0000 - lr: 4.2235e-05
# Epoch 73/100
# 215/215 [==============================] - 17s 80ms/step - loss: 0.0720 - accuracy: 0.9771 - val_loss: 2.6995e-04 - val_accuracy: 1.0000 - lr: 4.2235e-05
# Epoch 74/100
# 215/215 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.9774
# Epoch 74: ReduceLROnPlateau reducing learning rate to 3.167634986311896e-05.
# 215/215 [==============================] - 17s 81ms/step - loss: 0.0687 - accuracy: 0.9774 - val_loss: 3.2731e-04 - val_accuracy: 1.0000 - lr: 4.2235e-05
# Epoch 75/100
# 215/215 [==============================] - 17s 81ms/step - loss: 0.0661 - accuracy: 0.9788 - val_loss: 3.1574e-04 - val_accuracy: 1.0000 - lr: 3.1676e-05
# Epoch 76/100
# 215/215 [==============================] - 18s 84ms/step - loss: 0.0674 - accuracy: 0.9772 - val_loss: 3.1325e-04 - val_accuracy: 1.0000 - lr: 3.1676e-05
# Epoch 77/100
# 215/215 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9775
# Epoch 77: ReduceLROnPlateau reducing learning rate to 2.3757263079460245e-05.
# 215/215 [==============================] - 18s 81ms/step - loss: 0.0664 - accuracy: 0.9775 - val_loss: 2.3421e-04 - val_accuracy: 1.0000 - lr: 3.1676e-05
# Epoch 78/100
# 215/215 [==============================] - 19s 88ms/step - loss: 0.0674 - accuracy: 0.9773 - val_loss: 2.8594e-04 - val_accuracy: 1.0000 - lr: 2.3757e-05
# Epoch 79/100
# 215/215 [==============================] - 18s 84ms/step - loss: 0.0735 - accuracy: 0.9764 - val_loss: 3.3557e-04 - val_accuracy: 1.0000 - lr: 2.3757e-05
# Epoch 80/100
# 215/215 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9780
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.781794799171621e-05.
# 215/215 [==============================] - 20s 92ms/step - loss: 0.0661 - accuracy: 0.9780 - val_loss: 2.7463e-04 - val_accuracy: 1.0000 - lr: 2.3757e-05
# Epoch 81/100
# 215/215 [==============================] - 19s 87ms/step - loss: 0.0722 - accuracy: 0.9757 - val_loss: 3.6038e-04 - val_accuracy: 1.0000 - lr: 1.7818e-05
# Epoch 82/100
# 215/215 [==============================] - 20s 93ms/step - loss: 0.0673 - accuracy: 0.9779 - val_loss: 2.4083e-04 - val_accuracy: 1.0000 - lr: 1.7818e-05
# Epoch 83/100
# 215/215 [==============================] - 19s 89ms/step - loss: 0.0649 - accuracy: 0.9792 - val_loss: 2.7341e-04 - val_accuracy: 1.0000 - lr: 1.7818e-05
# Epoch 84/100
# 215/215 [==============================] - 21s 96ms/step - loss: 0.0665 - accuracy: 0.9787 - val_loss: 2.9998e-04 - val_accuracy: 1.0000 - lr: 1.7818e-05
# Epoch 85/100
# 215/215 [==============================] - 19s 90ms/step - loss: 0.0636 - accuracy: 0.9789 - val_loss: 3.1562e-04 - val_accuracy: 1.0000 - lr: 1.7818e-05
# Epoch 86/100
# 215/215 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9788
# Epoch 86: ReduceLROnPlateau reducing learning rate to 1.3363460311666131e-05.
# 215/215 [==============================] - 19s 90ms/step - loss: 0.0659 - accuracy: 0.9788 - val_loss: 2.5991e-04 - val_accuracy: 1.0000 - lr: 1.7818e-05
# Epoch 87/100
# 215/215 [==============================] - 19s 88ms/step - loss: 0.0683 - accuracy: 0.9789 - val_loss: 2.4702e-04 - val_accuracy: 1.0000 - lr: 1.3363e-05
# Epoch 88/100
# 215/215 [==============================] - 19s 89ms/step - loss: 0.0635 - accuracy: 0.9795 - val_loss: 2.4979e-04 - val_accuracy: 1.0000 - lr: 1.3363e-05
# Epoch 89/100
# 215/215 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9777
# Epoch 89: ReduceLROnPlateau reducing learning rate to 1.0022595233749598e-05.
# 215/215 [==============================] - 20s 91ms/step - loss: 0.0668 - accuracy: 0.9777 - val_loss: 2.3211e-04 - val_accuracy: 1.0000 - lr: 1.3363e-05
# Epoch 90/100
# 215/215 [==============================] - 19s 89ms/step - loss: 0.0617 - accuracy: 0.9800 - val_loss: 2.4459e-04 - val_accuracy: 1.0000 - lr: 1.0023e-05
# Epoch 91/100
# 215/215 [==============================] - 20s 92ms/step - loss: 0.0650 - accuracy: 0.9787 - val_loss: 2.6636e-04 - val_accuracy: 1.0000 - lr: 1.0023e-05
# Epoch 92/100
# 215/215 [==============================] - ETA: 0s - loss: 0.0676 - accuracy: 0.9775
# Epoch 92: ReduceLROnPlateau reducing learning rate to 1e-05.
# 215/215 [==============================] - 19s 87ms/step - loss: 0.0676 - accuracy: 0.9775 - val_loss: 2.6451e-04 - val_accuracy: 1.0000 - lr: 1.0023e-05
# Epoch 93/100
# 215/215 [==============================] - 20s 91ms/step - loss: 0.0682 - accuracy: 0.9777 - val_loss: 2.5519e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 94/100
# 215/215 [==============================] - 19s 89ms/step - loss: 0.0665 - accuracy: 0.9777 - val_loss: 2.5898e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 95/100
# 215/215 [==============================] - 20s 91ms/step - loss: 0.0610 - accuracy: 0.9807 - val_loss: 2.6899e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 96/100
# 215/215 [==============================] - 19s 89ms/step - loss: 0.0649 - accuracy: 0.9783 - val_loss: 2.4729e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 97/100
# 215/215 [==============================] - 20s 91ms/step - loss: 0.0614 - accuracy: 0.9794 - val_loss: 2.9633e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 98/100
# 215/215 [==============================] - 19s 86ms/step - loss: 0.0630 - accuracy: 0.9798 - val_loss: 2.7389e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 99/100
# 215/215 [==============================] - 19s 90ms/step - loss: 0.0675 - accuracy: 0.9777 - val_loss: 2.3255e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 100/100
# 215/215 [==============================] - 18s 84ms/step - loss: 0.0630 - accuracy: 0.9784 - val_loss: 2.3402e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Evaluate the Model

# %%
score = Model.evaluate(X_test) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# 225/225 [==============================] - 1s 4ms/step - loss: 2.3402e-04 - accuracy: 1.0000
# Test loss: 0.00023402208171319216
# Test accuracy: 1.0

# %%
df_test = pd.read_csv('/sign_mnist_test.csv')
y_test = df_test['label']
df_test.drop(['label'], axis=1, inplace=True)
X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

# %% [markdown]
# ## Confusion Matrix

# %%
y_pred = np.argmax(Model.predict(X_test),axis = 1)
# Out:
# 225/225 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import confusion_matrix
CM = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (15,15))
sns.heatmap(CM, annot=True, cmap="Blues", fmt = 'g')
plt.xlabel("Predicted Classes")
plt.ylabel("True Classes")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## Let's Test the Model

# %%
plt.figure(figsize=(15,15))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[i],cmap='gray')
    plt.ylabel(f"True: {alphabet[y_test[i]]}")
    plt.xlabel(f"Predicted: {alphabet[y_pred[i]]}")
    
plt.show()
